# %% [markdown]
# <a href="https://colab.research.google.com/github/gigDevelopment10/DeepInAI/blob/main/StableBases-LunarLander.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stable Baselines3 - Training, Saving and Loading
#
# Github Repo: [https://github.com/DLR-RM/stable-baselines3](https://github.com/DLR-RM/stable-baselines3)
#
#
# [RL Baselines3 Zoo](https://github.com/DLR-RM/rl-baselines3-zoo) is a collection of pre-trained Reinforcement Learning agents using Stable-Baselines3.
#
# It also provides basic scripts for training, evaluating agents, tuning hyperparameters and recording videos.
#
# Documentation is available online: [https://stable-baselines3.readthedocs.io/](https://stable-baselines3.readthedocs.io/)
#
# ## Install Dependencies and Stable Baselines Using Pip
#
#
# ```
# pip install stable-baselines3[extra]
# ```

# %%
# !apt-get update && apt-get install swig cmake
# !pip install stable-baselines3[extra] box2d box2d-kengz

# %% [markdown]
# ## Import policy, RL agent, ...

# %%
import gym
import numpy as np

from stable_baselines3 import DQN

# %% [markdown]
# ## Create the Gym env and instantiate the agent
#
# For this example, we will use Lunar Lander environment.
#
# "Landing outside landing pad is possible. Fuel is infinite, so an agent can learn to fly and then land on its first attempt. Four discrete actions available: do nothing, fire left orientation engine, fire main engine, fire right orientation engine. "
#
# Lunar Lander environment: [https://gym.openai.com/envs/LunarLander-v2/](https://gym.openai.com/envs/LunarLander-v2/)
#
# ![Lunar Lander](https://cdn-images-1.medium.com/max/960/1*f4VZPKOI0PYNWiwt0la0Rg.gif)
#
#
# We chose the MlpPolicy because input of Lunar Lander is a feature vector, not images.
#
# The type of action to use (discrete/continuous) will be automatically deduced from the environment action space

# %%
model = DQN('MlpPolicy', 'LunarLander-v2', verbose=1, exploration_final_eps=0.1, target_update_interval=250)
# Out:
# Using cuda device
# Creating environment from the given name 'LunarLander-v2'
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# We load a helper function to evaluate the agent:

# %%
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# Let's evaluate the un-trained agent, this should be a random agent.

# %%
# Separate env for evaluation
eval_env = gym.make('LunarLander-v2')

# Random Agent, before training
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)

print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# /usr/local/lib/python3.8/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# mean_reward=-127.27 +/- 25.774798925280695

# %% [markdown]
# ## Train the agent and save it
#
# Warning: this may take a while

# %%
# Train the agent
model.learn(total_timesteps=int(1e5))
# Save the agent
model.save("dqn_lunar")
del model  # delete trained model to demonstrate loading
# Out:
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94       |
# |    ep_rew_mean      | -119     |
# |    exploration_rate | 0.966    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1252     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 376      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87       |
# |    ep_rew_mean      | -186     |
# |    exploration_rate | 0.937    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1040     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 696      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.9     |
# |    ep_rew_mean      | -167     |
# |    exploration_rate | 0.902    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1017     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1091     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.9     |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.869    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1009     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1454     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.3     |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.834    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 977      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1847     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.7     |
# |    ep_rew_mean      | -201     |
# |    exploration_rate | 0.798    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 921      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2249     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.2     |
# |    ep_rew_mean      | -199     |
# |    exploration_rate | 0.765    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1006     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2611     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.7     |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.733    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1082     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2965     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.5     |
# |    ep_rew_mean      | -185     |
# |    exploration_rate | 0.697    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1151     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3365     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95       |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.658    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1218     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3798     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.1     |
# |    ep_rew_mean      | -194     |
# |    exploration_rate | 0.631    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1262     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4098     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.3     |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.597    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1308     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4478     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.4     |
# |    ep_rew_mean      | -193     |
# |    exploration_rate | 0.563    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1369     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4857     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93       |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.531    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1431     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5207     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.7     |
# |    ep_rew_mean      | -194     |
# |    exploration_rate | 0.5      |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1491     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5560     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.8     |
# |    ep_rew_mean      | -193     |
# |    exploration_rate | 0.466    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1548     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5936     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.1     |
# |    ep_rew_mean      | -194     |
# |    exploration_rate | 0.43     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1606     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 6330     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.3     |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.395    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1655     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6718     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93       |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.364    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1702     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 7068     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.8     |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.332    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1746     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 7425     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.1     |
# |    ep_rew_mean      | -198     |
# |    exploration_rate | 0.296    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1796     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 7823     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.1     |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.263    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1841     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 8194     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.8     |
# |    ep_rew_mean      | -193     |
# |    exploration_rate | 0.223    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1891     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 8628     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.5     |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.192    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1927     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 8980     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.2     |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.162    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1964     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 9315     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.7     |
# |    ep_rew_mean      | -190     |
# |    exploration_rate | 0.132    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1999     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 9643     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.9     |
# |    ep_rew_mean      | -186     |
# |    exploration_rate | 0.101    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 2030     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 9987     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.5     |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 2060     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 10339    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.2     |
# |    ep_rew_mean      | -194     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 2084     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 10679    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.1     |
# |    ep_rew_mean      | -194     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 2118     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 11058    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.6     |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 2149     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 11410    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | -194     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 2179     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 11760    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 2207     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 12116    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.6     |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 2237     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 12529    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.3     |
# |    ep_rew_mean      | -190     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 2260     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 12829    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.3     |
# |    ep_rew_mean      | -193     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 2287     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 13225    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.7     |
# |    ep_rew_mean      | -197     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 2307     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 13545    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.9     |
# |    ep_rew_mean      | -194     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 2328     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 13851    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.2     |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 2353     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 14226    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.3     |
# |    ep_rew_mean      | -197     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 2370     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 14592    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.7     |
# |    ep_rew_mean      | -194     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 2388     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 14904    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.3     |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 2411     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 15261    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.9     |
# |    ep_rew_mean      | -197     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 2431     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 15604    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.7     |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 2449     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 15942    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.7     |
# |    ep_rew_mean      | -199     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 2468     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 16291    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.5     |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 2485     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 16671    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.3     |
# |    ep_rew_mean      | -197     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 2501     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 17024    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.8     |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 2517     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 17403    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.6     |
# |    ep_rew_mean      | -194     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 2532     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 17736    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.1     |
# |    ep_rew_mean      | -197     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 2545     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 18127    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.6     |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 2561     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 18504    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.8     |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 2575     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 18869    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.8     |
# |    ep_rew_mean      | -194     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 2590     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 19216    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.2     |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 2606     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 19599    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.5     |
# |    ep_rew_mean      | -194     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 2619     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 20013    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.3     |
# |    ep_rew_mean      | -193     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 2631     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 20341    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.9     |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 2647     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 20747    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.3     |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 2662     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 21143    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.8     |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 2676     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 21505    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.2     |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 2685     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 21854    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.9     |
# |    ep_rew_mean      | -193     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 2694     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 22213    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.4     |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 2706     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 22583    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.8     |
# |    ep_rew_mean      | -193     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 2717     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 22936    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.4     |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 2728     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 23262    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.5     |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 2740     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 23641    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 2748     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 24050    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.4     |
# |    ep_rew_mean      | -190     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 2758     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 24398    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.3     |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 2769     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 24834    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.8     |
# |    ep_rew_mean      | -190     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 2780     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 25217    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.1     |
# |    ep_rew_mean      | -190     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 2789     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 25598    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.5     |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 2800     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 25924    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.6     |
# |    ep_rew_mean      | -186     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 2810     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 26282    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.2     |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 2818     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 26628    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.3     |
# |    ep_rew_mean      | -190     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 2827     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 27069    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.3     |
# |    ep_rew_mean      | -190     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 2837     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 27453    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.6     |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 2844     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 27764    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.8     |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 2852     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 28154    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93       |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 2861     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 28518    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.6     |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 2872     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 28957    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.7     |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 2878     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 29385    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94       |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 2886     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 29742    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.7     |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 2894     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 30114    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.5     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 2903     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 30494    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.3     |
# |    ep_rew_mean      | -183     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 2913     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 30933    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.7     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 2920     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 31328    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.5     |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 2928     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 31660    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.5     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 2935     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 32036    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.1     |
# |    ep_rew_mean      | -174     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 2942     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 32350    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.5     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 2950     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 32707    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.6     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 2953     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 33099    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95       |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 2961     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 33547    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.3     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 2965     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 34029    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.7     |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 2972     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 34401    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.4     |
# |    ep_rew_mean      | -167     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 2978     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 34757    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.3     |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 2984     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 35133    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.4     |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 2989     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 35463    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.1     |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 2993     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 35788    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.5     |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 2999     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 36178    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.9     |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 3004     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 36557    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.7     |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 3009     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 36923    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96       |
# |    ep_rew_mean      | -181     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 3014     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 37364    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.3     |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 3019     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 37785    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.7     |
# |    ep_rew_mean      | -186     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 3024     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 38084    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.7     |
# |    ep_rew_mean      | -185     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 3030     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 38431    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.3     |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 3034     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 38818    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.8     |
# |    ep_rew_mean      | -186     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 3039     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 39227    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.7     |
# |    ep_rew_mean      | -186     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 3044     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 39581    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.2     |
# |    ep_rew_mean      | -186     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 3049     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 39916    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.9     |
# |    ep_rew_mean      | -181     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 3053     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 40223    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.2     |
# |    ep_rew_mean      | -181     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 3058     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 40649    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.5     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 3061     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 41010    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.2     |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 3066     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 41360    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.1     |
# |    ep_rew_mean      | -174     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 3059     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 41661    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.7     |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 3053     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 41981    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.4     |
# |    ep_rew_mean      | -167     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 3047     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 42337    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.1     |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 3040     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 42754    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92       |
# |    ep_rew_mean      | -167     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 3032     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 43230    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.1     |
# |    ep_rew_mean      | -166     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 3026     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 43609    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.5     |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 3022     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 44005    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92       |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 3017     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 44336    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.1     |
# |    ep_rew_mean      | -165     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 3014     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 44670    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.7     |
# |    ep_rew_mean      | -166     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 3008     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 45055    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.3     |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 3003     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 45406    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.2     |
# |    ep_rew_mean      | -166     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 2999     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 45780    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.7     |
# |    ep_rew_mean      | -165     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 500      |
# ...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.8     |
# |    ep_rew_mean      | -157     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 2953     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 49401    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.1     |
# |    ep_rew_mean      | -157     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 2957     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 49855    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.3     |
# |    ep_rew_mean      | -158     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 2922     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 50137    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.18     |
# |    n_updates        | 34       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.3     |
# |    ep_rew_mean      | -174     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 2863     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 50490    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.35     |
# |    n_updates        | 122      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92       |
# |    ep_rew_mean      | -193     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 2803     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 50858    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.07     |
# |    n_updates        | 214      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.6     |
# |    ep_rew_mean      | -239     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 2686     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 51540    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.2      |
# |    n_updates        | 384      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.9     |
# |    ep_rew_mean      | -261     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 2615     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 52030    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.54     |
# |    n_updates        | 507      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.1     |
# |    ep_rew_mean      | -286     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 2544     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 52566    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.08     |
# |    n_updates        | 641      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -306     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 2446     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 53253    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.26     |
# |    n_updates        | 813      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 106      |
# |    ep_rew_mean      | -321     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 2330     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 54167    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.03     |
# |    n_updates        | 1041     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 112      |
# |    ep_rew_mean      | -321     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 2221     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 55191    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1        |
# |    n_updates        | 1297     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 135      |
# |    ep_rew_mean      | -318     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 1742     |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 57859    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.641    |
# |    n_updates        | 1964     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 149      |
# |    ep_rew_mean      | -316     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 1612     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 59612    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.818    |
# |    n_updates        | 2402     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | -318     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 1333     |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 63612    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.6      |
# |    n_updates        | 3402     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 208      |
# |    ep_rew_mean      | -319     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 1222     |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 66224    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.849    |
# |    n_updates        | 4055     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 237      |
# |    ep_rew_mean      | -314     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 1072     |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 69514    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.13     |
# |    n_updates        | 4878     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 258      |
# |    ep_rew_mean      | -303     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 1011     |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 71993    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.978    |
# |    n_updates        | 5498     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 273      |
# |    ep_rew_mean      | -291     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 989      |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 73825    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.999    |
# |    n_updates        | 5956     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 292      |
# |    ep_rew_mean      | -280     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 608      |
# |    fps              | 957      |
# |    time_elapsed     | 79       |
# |    total_timesteps  | 76113    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.824    |
# |    n_updates        | 6528     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 311      |
# |    ep_rew_mean      | -265     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 612      |
# |    fps              | 923      |
# |    time_elapsed     | 84       |
# |    total_timesteps  | 78401    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.563    |
# |    n_updates        | 7100     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 327      |
# |    ep_rew_mean      | -254     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 616      |
# |    fps              | 905      |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 80360    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.773    |
# |    n_updates        | 7589     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 338      |
# |    ep_rew_mean      | -245     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 620      |
# |    fps              | 894      |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 81820    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.66     |
# |    n_updates        | 7954     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 354      |
# |    ep_rew_mean      | -228     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 624      |
# |    fps              | 877      |
# |    time_elapsed     | 95       |
# |    total_timesteps  | 83696    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.831    |
# |    n_updates        | 8423     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 367      |
# |    ep_rew_mean      | -218     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 628      |
# |    fps              | 869      |
# |    time_elapsed     | 98       |
# |    total_timesteps  | 85365    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.49     |
# |    n_updates        | 8841     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 380      |
# |    ep_rew_mean      | -208     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 632      |
# |    fps              | 860      |
# |    time_elapsed     | 101      |
# |    total_timesteps  | 87043    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.686    |
# |    n_updates        | 9260     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 395      |
# |    ep_rew_mean      | -194     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 636      |
# |    fps              | 848      |
# |    time_elapsed     | 104      |
# |    total_timesteps  | 88896    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.968    |
# |    n_updates        | 9723     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 406      |
# |    ep_rew_mean      | -186     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 640      |
# |    fps              | 837      |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 90411    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.37     |
# |    n_updates        | 10102    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 425      |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 644      |
# |    fps              | 823      |
# |    time_elapsed     | 112      |
# |    total_timesteps  | 92629    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.08     |
# |    n_updates        | 10657    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 445      |
# |    ep_rew_mean      | -144     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 648      |
# |    fps              | 811      |
# |    time_elapsed     | 117      |
# |    total_timesteps  | 94992    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.661    |
# |    n_updates        | 11247    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 466      |
# |    ep_rew_mean      | -113     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 652      |
# |    fps              | 790      |
# |    time_elapsed     | 123      |
# |    total_timesteps  | 97452    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.702    |
# |    n_updates        | 11862    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 481      |
# |    ep_rew_mean      | -55.7    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 656      |
# |    fps              | 778      |
# |    time_elapsed     | 127      |
# |    total_timesteps  | 99624    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.38     |
# |    n_updates        | 12405    |
# ----------------------------------

# %% [markdown]
# ## Load the trained agent

# %%
model = DQN.load("dqn_lunar")

# %%
# Evaluate the trained agent
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)

print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# mean_reward=205.32 +/- 82.24376266223216
